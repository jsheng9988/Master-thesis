# %% [markdown]
# # Neural Network

# %% [markdown]
# ## Effect changing number hidden layers

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
hidden_layers = ['0', '1', '2', '3', '4', '5' ]
R2_H2O = [0.9653, 0.9364, 0.9332, 0.9080, 0.8615, 0.8316 ]

ax1 = fig.add_subplot(221) 
plt.plot(hidden_layers, R2_H2O , marker='o', linestyle='-', label = 'H$_2$O')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Number of hidden layers')
plt.ylabel('$R^2$ (average)')
plt.legend()

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
hidden_layers = ['0', '1', '2', '3', '4', '5' ]
R2_H2O = [3.0896e-05, 1.1012e-04, 2.0219e-04, 3.5229e-04, 4.4750e-04, 4.9396e-04]

ax1 = fig.add_subplot(221) 
plt.plot(hidden_layers, R2_H2O , marker='o', linestyle='-', label = 'H$_2$O')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Number of hidden layers')
plt.ylabel('RMSE')
plt.legend()

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
hidden_layers = ['0', '1', '2', '3', '4', '5' ]
R2_H2O = [20.8026, 37.8441, 45.5113, 58.3728, 73.1377, 78.5049]

ax1 = fig.add_subplot(221) 
plt.plot(hidden_layers, R2_H2O , marker='o', linestyle='-', label = 'H$_2$O')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Number of hidden layers')
plt.ylabel('MAPE (%)')
plt.legend()

plt.grid(False)
plt.show()

# %% [markdown]
# ## Effect changing number of neurons

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
hidden_layers = ['4', '8', '32', '64', '128', '256', '512' ]
R2_H2O = [0.6513, 0.8207, 0.9567, 0.9543, 0.9480, 0.9364 , 0.9384 ]

ax1 = fig.add_subplot(221) 
plt.plot(hidden_layers, R2_H2O , marker='o', linestyle='-', label = 'H$_2$O')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Number of neurons')
plt.ylabel('$R^2$ (average)')
plt.legend()

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
hidden_layers = ['4', '8', '32', '64', '128', '256', '512' ]
R2_H2O = [6.1128e-04, 3.2986e-04, 1.2957e-04, 1.0647e-04, 1.2035e-04, 1.1012e-04 , 1.1715e-04 ]

ax1 = fig.add_subplot(221) 
plt.plot(hidden_layers, R2_H2O , marker='o', linestyle='-', label = 'H$_2$O')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Number of neurons')
plt.ylabel('RMSE')
plt.legend()

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
hidden_layers = ['4', '8', '32', '64', '128', '256', '512' ]
R2_H2O = [106.5921, 45.1173, 34.8596, 33.0328, 34.1324, 37.8441 , 35.4772 ]

ax1 = fig.add_subplot(221) 
plt.plot(hidden_layers, R2_H2O , marker='o', linestyle='-', label = 'H$_2$O')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Number of neurons')
plt.ylabel('MAPE (%)')
plt.legend()

plt.grid(False)
plt.show()

# %% [markdown]
# ## Try different type of optimizer

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(12, 10))

train_test_percent = ['10/90', '20/80', '30/70', '40/60', '50/50', '60/40', '70/30', '80/20','90/10' ]
adam =  [0.9164 , 0.9607 , 0.9616 , 0.9607, 0.9653, 0.9640, 0.9663, 0.9646, 0.9619 ]
sgd = [0.2708, 0.4495, 0.6375, 0.8004, 0.8729, 0.8995, 0.9170, 0.9276, 0.9282]

ax1 = fig.add_subplot(221) 
plt.plot(train_test_percent, adam , marker='o', linestyle='-', label = 'Adam')
plt.plot(train_test_percent, sgd, marker='^', linestyle='-', label = 'SGD')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Train / Test percentage (%)')
plt.ylabel('$R^2$ (average)')
plt.legend()


plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(12, 10))

train_test_percent = ['10/90', '20/80', '30/70', '40/60', '50/50', '60/40', '70/30', '80/20','90/10' ]
adam =  [6.2699e-05 , 2.3160e-05 , 2.1228e-05 , 2.5414e-05, 3.0896e-05, 4.1969e-05, 2.9355e-05, 4.0133e-05, 4.2502e-05]
sgd = [1.5001e-03, 1.3201e-03, 1.0650e-03, 6.5039e-04, 4.6840e-04,3.7433e-04, 3.2192e-04, 2.8795e-04, 2.6443e-04]

ax1 = fig.add_subplot(221) 
plt.plot(train_test_percent, adam , marker='o', linestyle='-', label = 'Adam')
plt.plot(train_test_percent, sgd, marker='^', linestyle='-', label = 'SGD')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Train / Test percentage (%)')
plt.ylabel('RMSE')
plt.legend()


plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(12, 10))

train_test_percent = ['10/90', '20/80', '30/70', '40/60', '50/50', '60/40', '70/30', '80/20','90/10' ]
adam =  [31.1325 , 21.9972 , 22.1862 , 22.7833, 20.8026, 21.8768 , 21.1037, 21.9568, 23.6050 ]
sgd = [141.5725 , 119.1432 , 102.1256, 77.3742, 63.4196 ,54.9761, 51.1071, 46.5602, 42.6785]

ax1 = fig.add_subplot(221) 
plt.plot(train_test_percent, adam , marker='o', linestyle='-', label = 'Adam')
plt.plot(train_test_percent, sgd, marker='^', linestyle='-', label = 'SGD')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Train / Test percentage (%)')
plt.ylabel('MAPE (%)')
plt.legend()


plt.grid(False)
plt.show()

# %% [markdown]
# ## FIlter noise effect

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
train_test_percent = ['10/90', '20/80', '30/70', '40/60', '50/50', '60/40', '70/30', '80/20','90/10' ]
R2_unfilter = [0.9164, 0.9607, 0.9616, 0.9607, 0.9653, 0.9640, 0.9663 , 0.9646 , 0.9619  ]
R2_filtered = [0.9998, 0.9999, 0.9999, 0.9999, 0.9999, 0.9999, 0.9999 , 0.9999 , 0.9998  ]

ax1 = fig.add_subplot(221) 
plt.plot(train_test_percent, R2_unfilter , marker='o', linestyle='-', label = 'H$_2$O-original')
plt.plot(train_test_percent, R2_filtered , marker='^', linestyle='-', label = 'H$_2$O-removed zeros')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Train / Test percentage (%)')
plt.ylabel('$R^2$ (average)')
plt.legend()

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
train_test_percent = ['10/90', '20/80', '30/70', '40/60', '50/50', '60/40', '70/30', '80/20','90/10' ]
R2_unfilter = [6.2699e-05, 2.3160e-05, 2.1228e-05, 2.5414e-05, 3.0896e-05, 4.1969e-05, 2.9355e-05 , 4.0133e-05 , 4.2502e-05 ]
R2_filtered = [3.9836e-05, 2.2238e-05, 2.3352e-05, 1.7888e-05, 3.5559e-05, 2.4900e-05, 2.6616e-05 , 2.8381e-05, 4.1885e-05 ]

ax1 = fig.add_subplot(221) 
plt.plot(train_test_percent, R2_unfilter , marker='o', linestyle='-', label = 'H$_2$O-original')
plt.plot(train_test_percent, R2_filtered , marker='^', linestyle='-', label = 'H$_2$O-removed zeros')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Train / Test percentage (%)')
plt.ylabel('RMSE')
plt.legend()

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 10))
train_test_percent = ['10/90', '20/80', '30/70', '40/60', '50/50', '60/40', '70/30', '80/20','90/10' ]
R2_unfilter = [31.1325, 21.9972, 22.1862 , 22.7833, 20.8026, 21.8768 , 21.1037 , 21.9568 , 23.6050  ]
R2_filtered = [2.4458, 1.8379, 1.6666, 1.6141, 2.3548, 3.3991, 2.5147 , 2.7024, 3.0417]

ax1 = fig.add_subplot(221) 
plt.plot(train_test_percent, R2_unfilter , marker='o', linestyle='-', label = 'H$_2$O-original')
plt.plot(train_test_percent, R2_filtered , marker='^', linestyle='-', label = 'H$_2$O-removed zeros')

# Add annotations
# for i, (xi, yi) in enumerate(zip(train_percent, log_mse)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 7), ha='center')
plt.title('Test set')
plt.xlabel('Train / Test percentage (%)')
plt.ylabel('MAPE (%)')
plt.legend()

plt.grid(False)
plt.show()
